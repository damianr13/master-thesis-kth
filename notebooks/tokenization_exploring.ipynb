# %%
import os

if os.getcwd().endswith('notebooks'):
    os.chdir('..')
    
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = 'all'

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained('huawei-noah/TinyBERT_General_4L_312D', 
                                          additional_special_tokens=('[COL]', '[VAL]'))

tokenizer('Some test text with a complicatedbombastic word').tokens()
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.
# ['[CLS]',
#  'some',
#  'test',
#  'text',
#  'with',
#  'a',
#  'complicated',
#  '##bo',
#  '##mba',
#  '##stic',
#  'word',
#  '[SEP]']

# %%
import pandas as pd

train_set = pd.read_csv('data/processed/contrastive/amazon_google/pretrain-train.csv')
train_set.head()
# Out:
#                                                 text  cluster_id source
# 0  [COL] title [VAL] sony vegas movie studio + dv...         350     #1
# 1  [COL] title [VAL] adobe photoshop elements 4.0...        1030     #1
# 2  [COL] title [VAL] mcafee virusscan plus 3 user...         239     #1
# 3  [COL] title [VAL] microsoft windows vista home...         506     #1
# 4  [COL] title [VAL] punch ! professional home de...         444     #1

# %%
train_set['text_tokenized'] = train_set['text'].apply(lambda x: tokenizer(x).tokens())
train_set.head()
# Out:
#                                                 text  cluster_id source  \
# 0  [COL] title [VAL] sony vegas movie studio + dv...         350     #1
# 1  [COL] title [VAL] adobe photoshop elements 4.0...        1030     #1
# 2  [COL] title [VAL] mcafee virusscan plus 3 user...         239     #1
# 3  [COL] title [VAL] microsoft windows vista home...         506     #1
# 4  [COL] title [VAL] punch ! professional home de...         444     #1
#
#                                       text_tokenized
# 0  [[CLS], [COL], title, [VAL], sony, vegas, movi...
# 1  [[CLS], [COL], title, [VAL], adobe, photos, ##...
# 2  [[CLS], [COL], title, [VAL], mca, ##fe, ##e, v...
# 3  [[CLS], [COL], title, [VAL], microsoft, window...
# 4  [[CLS], [COL], title, [VAL], punch, !, profess...

# %%
from typing import List

def unite_tokens(tokens: List[str], index: int) -> List[str]:
    current_concat = tokens[index]
    i = index - 1
    result = []
    seed = [tokens[index]]
    while i > 0 and tokens[i + 1].startswith('##'):
        current_concat = tokens[i] + current_concat[2:]
        seed.insert(0, tokens[i])
        result.append((current_concat, tuple(seed)))
        i -= 1
        
    return result

def extract_possible_concatenations(tokens: List[str]) -> List[str]:
    result = []
    for i in range(len(tokens) - 1):
        if tokens[i + 1].startswith('##'):
            result += unite_tokens(tokens, i + 1)
            
    return result
        
train_set['potential_new_tokens'] = train_set['text_tokenized'].apply(extract_possible_concatenations)
train_set.head()
# Out:
#                                                 text  cluster_id source  \
# 0  [COL] title [VAL] sony vegas movie studio + dv...         350     #1
# 1  [COL] title [VAL] adobe photoshop elements 4.0...        1030     #1
# 2  [COL] title [VAL] mcafee virusscan plus 3 user...         239     #1
# 3  [COL] title [VAL] microsoft windows vista home...         506     #1
# 4  [COL] title [VAL] punch ! professional home de...         444     #1
#
#                                       text_tokenized  \
# 0  [[CLS], [COL], title, [VAL], sony, vegas, movi...
# 1  [[CLS], [COL], title, [VAL], adobe, photos, ##...
# 2  [[CLS], [COL], title, [VAL], mca, ##fe, ##e, v...
# 3  [[CLS], [COL], title, [VAL], microsoft, window...
# 4  [[CLS], [COL], title, [VAL], punch, !, profess...
#
#                                 potential_new_tokens
# 0                                                 []
# 1  [(photoshop, (photos, ##hop)), (29180, (291, #...
# 2  [(mcafe, (mca, ##fe)), (##fee, (##fe, ##e)), (...
# 3                                                 []
# 4                                                 []

# %%
tokens_df = pd.DataFrame()
tokens_df['option'] = train_set['potential_new_tokens']

tokens_df = tokens_df.explode('option')
tokens_df.dropna(inplace=True)

tokens_df = tokens_df.groupby('option').option.count().rename('count').reset_index()
tokens_df.head()
# Out:
#                                      option  count
# 0                      (##000, (##00, ##0))      9
# 1              (##00034, (##00, ##0, ##34))      1
# 2                (##0006, (##00, ##0, ##6))      2
# 3          (##0006w, (##00, ##0, ##6, ##w))      1
# 4  (##0006wwc, (##00, ##0, ##6, ##w, ##wc))      1

# %%
len(tokens_df)
# Out:
# 4289

# %%
tokens_df['option'].nunique()
# Out:
# 4289

# %%
present_at_least = len(train_set) // 200

# %%
tokens_df = tokens_df.sort_values('count', ascending=False)
tokens_df = tokens_df[tokens_df['count'] >= present_at_least]
tokens_df.head(len(tokens_df))
# Out:
#                                 option  count
# 2994                  (cs3, (cs, ##3))    149
# 3706      (photoshop, (photos, ##hop))     48
# 3785    (quickbooks, (quick, ##books))     47
# 4012              (syman, (sy, ##man))     46
# 1496        (##mantec, (##man, ##tec))     46
# ...                                ...    ...
# 3736  (printmaster, (print, ##master))     13
# 2758  (avanquest, (ava, ##n, ##quest))     13
# 3200        (firewall, (fire, ##wall))     13
# 1555        (##nquest, (##n, ##quest))     13
# 2757                (avan, (ava, ##n))     13
#
# [83 rows x 2 columns]

# %%
tokens_df['token'], tokens_df['seed'] = zip(*tokens_df['option'])
tokens_df.head(50)
# Out:
#                                   option  count       token  \
# 2994                    (cs3, (cs, ##3))    149         cs3
# 3706        (photoshop, (photos, ##hop))     48   photoshop
# 3785      (quickbooks, (quick, ##books))     47  quickbooks
# 4012                (syman, (sy, ##man))     46       syman
# 1496          (##mantec, (##man, ##tec))     46    ##mantec
# 4013      (symantec, (sy, ##man, ##tec))     46    symantec
# 2976                (corel, (core, ##l))     44       corel
# 3330              (intuit, (int, ##uit))     42      intuit
# 3123          (emedia, (em, ##ed, ##ia))     40      emedia
# 3122                  (emed, (em, ##ed))     40        emed
# 1257              (##edia, (##ed, ##ia))     40      ##edia
# 3282                (hoyle, (ho, ##yle))     39       hoyle
# 3641                (onone, (ono, ##ne))     37       onone
# 3699        (peachtree, (peach, ##tree))     34   peachtree
# 1634                (##pyr, (##py, ##r))     32       ##pyr
# 2737                  (aspy, (as, ##py))     32        aspy
# 2738            (aspyr, (as, ##py, ##r))     32       aspyr
# 1096          (##belius, (##bel, ##ius))     29    ##belius
# 3893                (sibel, (si, ##bel))     29       sibel
# 3894      (sibelius, (si, ##bel, ##ius))     29    sibelius
# 4209                (webro, (web, ##ro))     29       webro
# 1685              (##root, (##ro, ##ot))     29      ##root
# 4210        (webroot, (web, ##ro, ##ot))     29     webroot
# 2675        (acrobat, (ac, ##ro, ##bat))     25     acrobat
# 3927        (sonicwall, (sonic, ##wall))     25   sonicwall
# 2674                  (acro, (ac, ##ro))     25        acro
# 3975        (steinberg, (stein, ##berg))     25   steinberg
# 1683            (##robat, (##ro, ##bat))     25     ##robat
# 3203            (fogware, (fog, ##ware))     24     fogware
# 3217        (freeverse, (free, ##verse))     24   freeverse
# 1749              (##tart, (##tar, ##t))     23      ##tart
# 3369    (jumpstart, (jumps, ##tar, ##t))     23   jumpstart
# 3368          (jumpstar, (jumps, ##tar))     23    jumpstar
# 3786            (quicken, (quick, ##en))     23     quicken
# 2889          (cakewalk, (cake, ##walk))     22    cakewalk
# 2666              (abacus, (aba, ##cus))     22      abacus
# 1725              (##soft, (##so, ##ft))     21      ##soft
# 2709        (antivirus, (anti, ##virus))     21   antivirus
# 1227        (##derbund, (##der, ##bund))     20   ##derbund
# 1221              (##deep, (##dee, ##p))     20      ##deep
# 4114              (upsell, (ups, ##ell))     20      upsell
# 2291                      (1u, (1, ##u))     20          1u
# 3835    (riverdeep, (river, ##dee, ##p))     20   riverdeep
# 2862  (broderbund, (bro, ##der, ##bund))     20  broderbund
# 3834          (riverdee, (river, ##dee))     20    riverdee
# 2861              (broder, (bro, ##der))     20      broder
# 4175                    (vpn, (vp, ##n))     19         vpn
# 2700              (allume, (all, ##ume))     18      allume
# 3158      (essentials, (essential, ##s))     18  essentials
# 3169                  (exec, (ex, ##ec))     18        exec
#
#                       seed
# 2994             (cs, ##3)
# 3706       (photos, ##hop)
# 3785      (quick, ##books)
# 4012           (sy, ##man)
# 1496        (##man, ##tec)
# 4013    (sy, ##man, ##tec)
# 2976           (core, ##l)
# 3330          (int, ##uit)
# 3123      (em, ##ed, ##ia)
# 3122            (em, ##ed)
# 1257          (##ed, ##ia)
# 3282           (ho, ##yle)
# 3641           (ono, ##ne)
# 3699       (peach, ##tree)
# 1634           (##py, ##r)
# 2737            (as, ##py)
# 2738       (as, ##py, ##r)
# 1096        (##bel, ##ius)
# 3893           (si, ##bel)
# 3894    (si, ##bel, ##ius)
# 4209           (web, ##ro)
# 1685          (##ro, ##ot)
# 4210     (web, ##ro, ##ot)
# 2675     (ac, ##ro, ##bat)
# 3927       (sonic, ##wall)
# 2674            (ac, ##ro)
# 3975       (stein, ##berg)
# 1683         (##ro, ##bat)
# 3203         (fog, ##ware)
# 3217       (free, ##verse)
# 1749          (##tar, ##t)
# 3369   (jumps, ##tar, ##t)
# 3368        (jumps, ##tar)
# 3786         (quick, ##en)
# 2889        (cake, ##walk)
# 2666          (aba, ##cus)
# 1725          (##so, ##ft)
# 2709       (anti, ##virus)
# 1227       (##der, ##bund)
# 1221          (##dee, ##p)
# 4114          (ups, ##ell)
# 2291              (1, ##u)
# 3835   (river, ##dee, ##p)
# 2862  (bro, ##der, ##bund)
# 3834        (river, ##dee)
# 2861          (bro, ##der)
# 4175             (vp, ##n)
# 2700          (all, ##ume)
# 3158      (essential, ##s)
# 3169            (ex, ##ec)

# %%
all_seeds = tokens_df['seed'].tolist()

clustered_seeds = {}
for seed in all_seeds:
    cluster = len(seed)
    if cluster not in clustered_seeds:
        clustered_seeds[cluster] = []
        
    clustered_seeds[cluster].append(seed)
    
useless_seeds = []
for k in clustered_seeds.keys():
    if k + 1 not in clustered_seeds:
        break
    
    for lower_rank_seed in clustered_seeds[k]:
        for higher_rank_seed in clustered_seeds[k+1]:
            if set(lower_rank_seed).issubset(set(higher_rank_seed)):
                useless_seeds.append(lower_rank_seed)
                
print(useless_seeds)

tokens_df = tokens_df[~tokens_df['seed'].isin(useless_seeds)]
tokens_df.head(50)
# Out:
# [('sy', '##man'), ('##man', '##tec'), ('em', '##ed'), ('##ed', '##ia'), ('##py', '##r'), ('as', '##py'), ('##bel', '##ius'), ('si', '##bel'), ('web', '##ro'), ('##ro', '##ot'), ('ac', '##ro'), ('##ro', '##bat'), ('##tar', '##t'), ('jumps', '##tar'), ('##der', '##bund'), ('##dee', '##p'), ('river', '##dee'), ('bro', '##der'), ('mca', '##fe'), ('##fe', '##e'), ('retro', '##sp'), ('##sp', '##ot'), ('micro', '##sp'), ('##sp', '##ect'), ('##er', '##ve'), ('##put', '##race'), ('arcs', '##er'), ('com', '##put'), ('##co', '##on'), ('ty', '##co'), ('##n', '##quest'), ('ava', '##n')]
#                                   option  count        token  \
# 2994                    (cs3, (cs, ##3))    149          cs3
# 3706        (photoshop, (photos, ##hop))     48    photoshop
# 3785      (quickbooks, (quick, ##books))     47   quickbooks
# 4013      (symantec, (sy, ##man, ##tec))     46     symantec
# 2976                (corel, (core, ##l))     44        corel
# 3330              (intuit, (int, ##uit))     42       intuit
# 3123          (emedia, (em, ##ed, ##ia))     40       emedia
# 3282                (hoyle, (ho, ##yle))     39        hoyle
# 3641                (onone, (ono, ##ne))     37        onone
# 3699        (peachtree, (peach, ##tree))     34    peachtree
# 2738            (aspyr, (as, ##py, ##r))     32        aspyr
# 3894      (sibelius, (si, ##bel, ##ius))     29     sibelius
# 4210        (webroot, (web, ##ro, ##ot))     29      webroot
# 2675        (acrobat, (ac, ##ro, ##bat))     25      acrobat
# 3927        (sonicwall, (sonic, ##wall))     25    sonicwall
# 3975        (steinberg, (stein, ##berg))     25    steinberg
# 3203            (fogware, (fog, ##ware))     24      fogware
# 3217        (freeverse, (free, ##verse))     24    freeverse
# 3369    (jumpstart, (jumps, ##tar, ##t))     23    jumpstart
# 3786            (quicken, (quick, ##en))     23      quicken
# 2889          (cakewalk, (cake, ##walk))     22     cakewalk
# 2666              (abacus, (aba, ##cus))     22       abacus
# 1725              (##soft, (##so, ##ft))     21       ##soft
# 2709        (antivirus, (anti, ##virus))     21    antivirus
# 4114              (upsell, (ups, ##ell))     20       upsell
# 2291                      (1u, (1, ##u))     20           1u
# 3835    (riverdeep, (river, ##dee, ##p))     20    riverdeep
# 2862  (broderbund, (bro, ##der, ##bund))     20   broderbund
# 4175                    (vpn, (vp, ##n))     19          vpn
# 2700              (allume, (all, ##ume))     18       allume
# 3158      (essentials, (essential, ##s))     18   essentials
# 3169                  (exec, (ex, ##ec))     18         exec
# 3489          (mcafee, (mca, ##fe, ##e))     17       mcafee
# 3394            (laptops, (laptop, ##s))     17      laptops
# 4009            (sweeper, (sweep, ##er))     17      sweeper
# 3487                (mavis, (ma, ##vis))     17        mavis
# 3504    (microspot, (micro, ##sp, ##ot))     16    microspot
# 3823  (retrospect, (retro, ##sp, ##ect))     16   retrospect
# 2953  (computrace, (com, ##put, ##race))     16   computrace
# 3413              (lojack, (lo, ##jack))     16       lojack
# 3591            (netware, (net, ##ware))     16      netware
# 2728      (arcserve, (arcs, ##er, ##ve))     16     arcserve
# 3121                    (emc, (em, ##c))     16          emc
# 4062                      (tm, (t, ##m))     14           tm
# 4078          (tycoon, (ty, ##co, ##on))     14       tycoon
# 3961                    (ssc, (ss, ##c))     13          ssc
# 3502          (micromat, (micro, ##mat))     13     micromat
# 2996                  (csdc, (cs, ##dc))     13         csdc
# 3736    (printmaster, (print, ##master))     13  printmaster
# 2758    (avanquest, (ava, ##n, ##quest))     13    avanquest
#
#                       seed
# 2994             (cs, ##3)
# 3706       (photos, ##hop)
# 3785      (quick, ##books)
# 4013    (sy, ##man, ##tec)
# 2976           (core, ##l)
# 3330          (int, ##uit)
# 3123      (em, ##ed, ##ia)
# 3282           (ho, ##yle)
# 3641           (ono, ##ne)
# 3699       (peach, ##tree)
# 2738       (as, ##py, ##r)
# 3894    (si, ##bel, ##ius)
# 4210     (web, ##ro, ##ot)
# 2675     (ac, ##ro, ##bat)
# 3927       (sonic, ##wall)
# 3975       (stein, ##berg)
# 3203         (fog, ##ware)
# 3217       (free, ##verse)
# 3369   (jumps, ##tar, ##t)
# 3786         (quick, ##en)
# 2889        (cake, ##walk)
# 2666          (aba, ##cus)
# 1725          (##so, ##ft)
# 2709       (anti, ##virus)
# 4114          (ups, ##ell)
# 2291              (1, ##u)
# 3835   (river, ##dee, ##p)
# 2862  (bro, ##der, ##bund)
# 4175             (vp, ##n)
# 2700          (all, ##ume)
# 3158      (essential, ##s)
# 3169            (ex, ##ec)
# 3489      (mca, ##fe, ##e)
# 3394         (laptop, ##s)
# 4009         (sweep, ##er)
# 3487           (ma, ##vis)
# 3504   (micro, ##sp, ##ot)
# 3823  (retro, ##sp, ##ect)
# 2953  (com, ##put, ##race)
# 3413          (lo, ##jack)
# 3591         (net, ##ware)
# 2728    (arcs, ##er, ##ve)
# 3121             (em, ##c)
# 4062              (t, ##m)
# 4078      (ty, ##co, ##on)
# 3961             (ss, ##c)
# 3502        (micro, ##mat)
# 2996            (cs, ##dc)
# 3736     (print, ##master)
# 2758   (ava, ##n, ##quest)

# %%
vocab = tokenizer.get_vocab()

def translate_tokens_to_ids(tokens: List[str]) -> List[int]:
    return [vocab[t] for t in tokens]

tokens_df['seed_numeric'] = tokens_df['seed'].apply(lambda x: [vocab[t] for t in x])
tokens_df.head(50)
# Out:
#                                   option  count        token  \
# 2994                    (cs3, (cs, ##3))    149          cs3
# 3706        (photoshop, (photos, ##hop))     48    photoshop
# 3785      (quickbooks, (quick, ##books))     47   quickbooks
# 4013      (symantec, (sy, ##man, ##tec))     46     symantec
# 2976                (corel, (core, ##l))     44        corel
# 3330              (intuit, (int, ##uit))     42       intuit
# 3123          (emedia, (em, ##ed, ##ia))     40       emedia
# 3282                (hoyle, (ho, ##yle))     39        hoyle
# 3641                (onone, (ono, ##ne))     37        onone
# 3699        (peachtree, (peach, ##tree))     34    peachtree
# 2738            (aspyr, (as, ##py, ##r))     32        aspyr
# 3894      (sibelius, (si, ##bel, ##ius))     29     sibelius
# 4210        (webroot, (web, ##ro, ##ot))     29      webroot
# 2675        (acrobat, (ac, ##ro, ##bat))     25      acrobat
# 3927        (sonicwall, (sonic, ##wall))     25    sonicwall
# 3975        (steinberg, (stein, ##berg))     25    steinberg
# 3203            (fogware, (fog, ##ware))     24      fogware
# 3217        (freeverse, (free, ##verse))     24    freeverse
# 3369    (jumpstart, (jumps, ##tar, ##t))     23    jumpstart
# 3786            (quicken, (quick, ##en))     23      quicken
# 2889          (cakewalk, (cake, ##walk))     22     cakewalk
# 2666              (abacus, (aba, ##cus))     22       abacus
# 1725              (##soft, (##so, ##ft))     21       ##soft
# 2709        (antivirus, (anti, ##virus))     21    antivirus
# 4114              (upsell, (ups, ##ell))     20       upsell
# 2291                      (1u, (1, ##u))     20           1u
# 3835    (riverdeep, (river, ##dee, ##p))     20    riverdeep
# 2862  (broderbund, (bro, ##der, ##bund))     20   broderbund
# 4175                    (vpn, (vp, ##n))     19          vpn
# 2700              (allume, (all, ##ume))     18       allume
# 3158      (essentials, (essential, ##s))     18   essentials
# 3169                  (exec, (ex, ##ec))     18         exec
# 3489          (mcafee, (mca, ##fe, ##e))     17       mcafee
# 3394            (laptops, (laptop, ##s))     17      laptops
# 4009            (sweeper, (sweep, ##er))     17      sweeper
# 3487                (mavis, (ma, ##vis))     17        mavis
# 3504    (microspot, (micro, ##sp, ##ot))     16    microspot
# 3823  (retrospect, (retro, ##sp, ##ect))     16   retrospect
# 2953  (computrace, (com, ##put, ##race))     16   computrace
# 3413              (lojack, (lo, ##jack))     16       lojack
# 3591            (netware, (net, ##ware))     16      netware
# 2728      (arcserve, (arcs, ##er, ##ve))     16     arcserve
# 3121                    (emc, (em, ##c))     16          emc
# 4062                      (tm, (t, ##m))     14           tm
# 4078          (tycoon, (ty, ##co, ##on))     14       tycoon
# 3961                    (ssc, (ss, ##c))     13          ssc
# 3502          (micromat, (micro, ##mat))     13     micromat
# 2996                  (csdc, (cs, ##dc))     13         csdc
# 3736    (printmaster, (print, ##master))     13  printmaster
# 2758    (avanquest, (ava, ##n, ##quest))     13    avanquest
#
#                       seed           seed_numeric
# 2994             (cs, ##3)          [20116, 2509]
# 3706       (photos, ##hop)          [7760, 18471]
# 3785      (quick, ##books)          [4248, 17470]
# 4013    (sy, ##man, ##tec)   [25353, 2386, 26557]
# 2976           (core, ##l)           [4563, 2140]
# 3330          (int, ##uit)         [20014, 14663]
# 3123      (em, ##ed, ##ia)     [7861, 2098, 2401]
# 3282           (ho, ##yle)          [7570, 12844]
# 3641           (ono, ##ne)          [21058, 2638]
# 3699       (peach, ##tree)         [18237, 13334]
# 2738       (as, ##py, ##r)     [2004, 7685, 2099]
# 3894    (si, ##bel, ##ius)     [9033, 8671, 4173]
# 4210     (web, ##ro, ##ot)     [4773, 3217, 4140]
# 2675     (ac, ##ro, ##bat)    [9353, 3217, 14479]
# 3927       (sonic, ##wall)          [12728, 9628]
# 3975       (stein, ##berg)          [14233, 4059]
# 3203         (fog, ##ware)           [9666, 8059]
# 3217       (free, ##verse)          [2489, 16070]
# 3369   (jumps, ##tar, ##t)    [14523, 7559, 2102]
# 3786         (quick, ##en)           [4248, 2368]
# 2889        (cake, ##walk)          [9850, 17122]
# 2666          (aba, ##cus)          [19557, 7874]
# 1725          (##so, ##ft)           [6499, 6199]
# 2709       (anti, ##virus)          [3424, 23350]
# 4114          (ups, ##ell)          [11139, 5349]
# 2291              (1, ##u)           [1015, 2226]
# 3835   (river, ##dee, ##p)    [2314, 26095, 2361]
# 2862  (bro, ##der, ##bund)   [22953, 4063, 27265]
# 4175             (vp, ##n)          [21210, 2078]
# 2700          (all, ##ume)          [2035, 17897]
# 3158      (essential, ##s)           [6827, 2015]
# 3169            (ex, ##ec)           [4654, 8586]
# 3489      (mca, ##fe, ##e)    [22432, 7959, 2063]
# 3394         (laptop, ##s)          [12191, 2015]
# 4009         (sweep, ##er)          [11740, 2121]
# 3487           (ma, ##vis)          [5003, 11365]
# 3504   (micro, ##sp, ##ot)   [12702, 13102, 4140]
# 3823  (retro, ##sp, ##ect)  [22307, 13102, 22471]
# 2953  (com, ##put, ##race)   [4012, 18780, 22903]
# 3413          (lo, ##jack)          [8840, 17364]
# 3591         (net, ##ware)           [5658, 8059]
# 2728    (arcs, ##er, ##ve)    [29137, 2121, 3726]
# 3121             (em, ##c)           [7861, 2278]
# 4062              (t, ##m)           [1056, 2213]
# 4078      (ty, ##co, ##on)     [5939, 3597, 2239]
# 3961             (ss, ##c)           [7020, 2278]
# 3502        (micro, ##mat)         [12702, 18900]
# 2996            (cs, ##dc)         [20116, 16409]
# 3736     (print, ##master)           [6140, 8706]
# 2758   (ava, ##n, ##quest)   [10927, 2078, 15500]

# %%
tokenizer.add_tokens(tokens_df['token'].tolist(), special_tokens=True)
# Out:
# 51

# %%
tokenizer.get_vocab()['csdc']
# Out:
# 30571

# %%
dict(zip(tokens_df['token'].tolist(), tokens_df['seed_numeric'].tolist()))
# Out:
# {'cs3': [20116, 2509],
#  'photoshop': [7760, 18471],
#  'quickbooks': [4248, 17470],
#  'symantec': [25353, 2386, 26557],
#  'corel': [4563, 2140],
#  'intuit': [20014, 14663],
#  'emedia': [7861, 2098, 2401],
#  'hoyle': [7570, 12844],
#  'onone': [21058, 2638],
#  'peachtree': [18237, 13334],
#  'aspyr': [2004, 7685, 2099],
#  'sibelius': [9033, 8671, 4173],
#  'webroot': [4773, 3217, 4140],
#  'acrobat': [9353, 3217, 14479],
#  'sonicwall': [12728, 9628],
#  'steinberg': [14233, 4059],
#  'fogware': [9666, 8059],
#  'freeverse': [2489, 16070],
#  'jumpstart': [14523, 7559, 2102],
#  'quicken': [4248, 2368],
#  'cakewalk': [9850, 17122],
#  'abacus': [19557, 7874],
#  '##soft': [6499, 6199],
#  'antivirus': [3424, 23350],
#  'upsell': [11139, 5349],
#  '1u': [1015, 2226],
#  'riverdeep': [2314, 26095, 2361],
#  'broderbund': [22953, 4063, 27265],
#  'vpn': [21210, 2078],
#  'allume': [2035, 17897],
#  'essentials': [6827, 2015],
#  'exec': [4654, 8586],
#  'mcafee': [22432, 7959, 2063],
#  'laptops': [12191, 2015],
#  'sweeper': [11740, 2121],
#  'mavis': [5003, 11365],
#  'microspot': [12702, 13102, 4140],
#  'retrospect': [22307, 13102, 22471],
#  'computrace': [4012, 18780, 22903],
#  'lojack': [8840, 17364],
#  'netware': [5658, 8059],
#  'arcserve': [29137, 2121, 3726],
#  'emc': [7861, 2278],
#  'tm': [1056, 2213],
#  'tycoon': [5939, 3597, 2239],
#  'ssc': [7020, 2278],
#  'micromat': [12702, 18900],
#  'csdc': [20116, 16409],
#  'printmaster': [6140, 8706],
#  'avanquest': [10927, 2078, 15500],
#  'firewall': [2543, 9628]}

# %% [markdown]
# # Fidling with the transformer

# %%
from transformers import AutoModel

transformer = AutoModel.from_pretrained('huawei-noah/TinyBERT_General_4L_312D')

transformer.embeddings.word_embeddings
# Out:
# Some weights of the model checkpoint at huawei-noah/TinyBERT_General_4L_312D were not used when initializing BertModel: ['cls.seq_relationship.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.bias', 'fit_denses.2.bias', 'fit_denses.3.weight', 'fit_denses.0.weight', 'cls.predictions.transform.LayerNorm.bias', 'fit_denses.1.bias', 'fit_denses.3.bias', 'fit_denses.4.weight', 'cls.predictions.decoder.weight', 'fit_denses.0.bias', 'cls.seq_relationship.weight', 'fit_denses.2.weight', 'fit_denses.1.weight', 'cls.predictions.transform.LayerNorm.weight', 'fit_denses.4.bias']
# - This IS expected if you are initializing BertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Embedding(30522, 312, padding_idx=0)

# %%
len(tokenizer.get_vocab())
# Out:
# 30524

# %%
tokenizer('cs ##3').tokens()
# Out:
# ['[CLS]', 'cs', '#', '#', '3', '[SEP]']
